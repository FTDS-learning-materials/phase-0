# %% [markdown]
# # Debugging Exercise

# %% [markdown]
# ## Setup

# %% [markdown]
# Gunakan dataset berikut:
#
# ```sql
# CREATE TABLE sales (
#     id INT PRIMARY KEY,
#     product_name VARCHAR(50),
#     category VARCHAR(50),
#     price DECIMAL(10, 2),
#     quantity INT,
#     sale_date DATE
# );
#
# INSERT INTO sales (id, product_name, category, price, quantity, sale_date) VALUES
# (1, 'Laptop', 'Electronics', 1000.00, 5, '2024-12-01'),
# (2, 'Headphones', 'Electronics', 200.00, 10, '2024-12-02'),
# (3, 'Coffee Mug', 'Home', 15.00, 50, '2024-12-03'),
# (4, 'Notebook', 'Stationery', 5.00, 100, '2024-12-03'),
# (5, 'Smartphone', 'Electronics', 800.00, 8, '2024-12-04'),
# (6, 'Pen', 'Stationery', 2.00, 200, '2024-12-04');
# ```
#
# **Note**: You must use pgAdmin to complete this exercise!

# %% [markdown]
# ## 1. New Column
# Fix the following query to add new column `discount` on `sales` table to record product discount. This column is `DECIMAL(5,2)` and have default value of `0.00`.
#
# ```sql
# ALTER TABLE sales
# ADD discount DEFAULT 0,0 DECIMAL(5,2);
# ```

# %% [markdown]
# ## 2. Insert New Data
# Fix the following query to add new data into `sales` table
# ```sql
# INSERT INTO sales (product_name, category, price, quantity)
# VALUES ('Gaming Chair', 'Furniture', 150.00, 20);
# ```

# %% [markdown]
# ## 3. Update Product Price
#
# Fix the following query to change the price of `Pen` in `Stationery` category to `2.50`
#
# ```sql
# UPDATE sales
# SET price = 2,50
# WHERE product_name == 'Pen';
# ```

# %% [markdown]
# ## 4. Remove Old Sales
#
# Fix the following query to remove `sales` record before `3rd December 2024`
# ```sql
# DELETE FROM sales
# WHERE sale_date < 2024-12-03;
# ```

# %% [markdown]
# ## 5. Top Sales per Category
#
# Fix the following query to produce the expected output:
#
# | category | total_sales |
# | --- | --- |
# | Furniture | 3000.00 |
# | Electronics | 6400.00 |
# | Home | 750.00 |
# | Stationery | 1000.00 |
#
# ```sql
# SELECT category, SUM(price) AS total_sales
# FROM sales
# ```

# %% [markdown]
# ## 6. Most Expensive Product in Each Category
#
# Fix the following query to produce the expected output:
#
# | category | product_name | price
# | --- | --- | --- |
# | Electronics | Smartphone | 800.00
# | Home | Coffee Mug | 15.00
# | Stationery | Notebook | 5.00
# | Furniture | Gaming Chair | 150.00
#
# ```sql
# SELECT category, product_name, MAX(price) AS price
# FROM sales
# GROUP BY category;
# ```

# %% [markdown]
# ## 7. Classify Sales Based on Revenue
#
# Fix the following query to produce the expected output:
#
# | product_name | price | quantity | revenue_class
# | --- | --- | --- | ---
# | Coffee Mug | 15.00 | 50 | Low
# | Notebook | 5.00 | 100 | Low
# | Smartphone | 800.00 | 8 | High
# | Gaming Chair | 150.00 | 20 | Medium
# | Pen | 2.50 | 200 | Low
#
# **Note**:
# - Revenue is `price x quantity`
# - Using `Case-When`
# - If Revenue is higher than 5000 -> `revenue_class` is `High`
# - If Revenue is between 1000 to 5000 -> `revenue_class` is `Medium`
# - If Revenue is lower than 1000 -> `revenue_class` is `Low`
#
#
# ```sql
# SELECT product_name, price, quantity
# FROM sales;
# ```
